# %% [markdown]
# # CSC413 Final Project

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Imports

# %%
# need to restart runtime after running this block for the first time
# this code block needs to run twice
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-3.4.1-py3-none-any.whl (137 kB)
#      |████████████████████████████████| 137 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.7/dist-packages (from wfdb) (1.21.6)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from wfdb) (2.23.0)
# Collecting matplotlib>=3.3.4
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 26.3 MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from wfdb) (1.4.1)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from wfdb) (1.3.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.4->wfdb) (3.0.8)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.32.0-py3-none-any.whl (900 kB)
#      |████████████████████████████████| 900 kB 39.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.4->wfdb) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->wfdb) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->wfdb) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8.1->wfdb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8.1->wfdb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8.1->wfdb) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.8.1->wfdb) (3.0.4)
# Installing collected packages: fonttools, matplotlib, wfdb
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed fonttools-4.32.0 matplotlib-3.5.1 wfdb-3.4.1

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.21.6)

# %%
# libraries

import numpy as np
import torch
import torch.nn as nn

import os
import wfdb
import pickle
from sklearn import preprocessing
from scipy.signal import find_peaks
from tqdm import tqdm
from sklearn import model_selection

from torch.autograd import Variable

# %% [markdown]
# ### Download Data

# %%
wfdb.dl_database('mitdb', os.path.join(os.getcwd(), 'mitdb'))
# Out:
# Generating record list for: 100
# Generating record list for: 101
# Generating record list for: 102
# Generating record list for: 103
# Generating record list for: 104
# Generating record list for: 105
# Generating record list for: 106
# Generating record list for: 107
# Generating record list for: 108
# Generating record list for: 109
# Generating record list for: 111
# Generating record list for: 112
# Generating record list for: 113
# Generating record list for: 114
# Generating record list for: 115
# Generating record list for: 116
# Generating record list for: 117
# Generating record list for: 118
# Generating record list for: 119
# Generating record list for: 121
# Generating record list for: 122
# Generating record list for: 123
# Generating record list for: 124
# Generating record list for: 200
# Generating record list for: 201
# Generating record list for: 202
# Generating record list for: 203
# Generating record list for: 205
# Generating record list for: 207
# Generating record list for: 208
# Generating record list for: 209
# Generating record list for: 210
# Generating record list for: 212
# Generating record list for: 213
# Generating record list for: 214
# Generating record list for: 215
# Generating record list for: 217
# Generating record list for: 219
# Generating record list for: 220
# Generating record list for: 221
# Generating record list for: 222
# Generating record list for: 223
# Generating record list for: 228
# Generating record list for: 230
# Generating record list for: 231
# Generating record list for: 232
# Generating record list for: 233
# Generating record list for: 234
# Generating list of all files for: 100
# Generating list of all files for: 101
# Generating list of all files for: 102
# Generating list of all files for: 103
# Generating list of all files for: 104
# Generating list of all files for: 105
# Generating list of all files for: 106
# Generating list of all files for: 107
# Generating list of all files for: 108
# Generating list of all files for: 109
# Generating list of all files for: 111
# Generating list of all files for: 112
# Generating list of all files for: 113
# Generating list of all files for: 114
# Generating list of all files for: 115
# Generating list of all files for: 116
# Generating list of all files for: 117
# Generating list of all files for: 118
# Generating list of all files for: 119
# Generating list of all files for: 121
# Generating list of all files for: 122
# Generating list of all files for: 123
# Generating list of all files for: 124
# Generating list of all files for: 200
# Generating list of all files for: 201
# Generating list of all files for: 202
# Generating list of all files for: 203
# Generating list of all files for: 205
# Generating list of all files for: 207
# Generating list of all files for: 208
# Generating list of all files for: 209
# Generating list of all files for: 210
# Generating list of all files for: 212
# Generating list of all files for: 213
# Generating list of all files for: 214
# Generating list of all files for: 215
# Generating list of all files for: 217
# Generating list of all files for: 219
# Generating list of all files for: 220
# Generating list of all files for: 221
# Generating list of all files for: 222
# Generating list of all files for: 223
# Generating list of all files for: 228
# Generating list of all files for: 230
# Generating list of all files for: 231
# Generating list of all files for: 232
# Generating list of all files for: 233
# Generating list of all files for: 234
# Downloading files...
# Finished downloading files

# %%
# record and annotation for sample 100
record = wfdb.rdrecord('mitdb/100', sampto=3000)
annotation = wfdb.rdann('mitdb/100', 'atr', sampto=3000)
print(annotation)
# Out:
# <wfdb.io.annotation.Annotation object at 0x7f51305986d0>

# %% [markdown]
# `record` is `<class 'wfdb.io.record.Record'>`
#
# `annotation` is `<class 'wfdb.io.annotation.Annotation'>`

# %% [markdown]
# ### Plot

# %%
wfdb.plot_wfdb(record=record, annotation=annotation, plot_sym=True,
                   time_units='seconds', title='MIT-BIH Record 100',
                   figsize=(10,4), ecg_grids='all')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2092         ratio : float
#    2093             The ratio of logical to physical pixels used for the canvas.
# -> 2094
#    2095         Returns
#    2096         -------
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in _get_renderer(figure, print_method)
#    1558     figure.draw_without_rendering()
#    1559
# -> 1560
#    1561 def _is_non_interactive_terminal_ipython(ip):
#    1562     """
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     503             Metadata in the PNG file as key-value pairs of bytes or latin-1
#     504             encodable strings.
# --> 505             According to the PNG specification, keys must be shorter than 79
#     506             chars.
#     507
#
# ImportError: cannot import name '_png' from 'matplotlib' (/usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py)

# %% [markdown]
# ### Data Description

# %% [markdown]
# information regarding `<class 'wfdb.io.annotation.Annotation'>` and `<class 'wfdb.io.annotation.Annotation'>` can be found on this
# [link](https://wfdb.readthedocs.io/en/latest/io.html#module-wfdb.io) or run the code block below

# %%
# help(wfdb.Annotation)

# %%
# help(wfdb.Record)

# %% [markdown]
# ### Data Preprocessing

# %%
# ONLY RUN THIS IF YOU PLAN ON REPROCESSING DATA
# !rm -r processed_data
# Out:
# rm: cannot remove 'processed_data': No such file or directory

# %%
# all the files
file_name = ['100','101','102','103','104','105','106','107','108','109',
             '111','112','113','114','115','116','117','118','119','121',
             '122','123','124','200','201','202','203','205','207','208',
             '209','210','212','213','214','215','217','219','220','221',
             '222','223','228','230','231','232','233','234']

# file_name = ['222','223','228','230','231']
# file_name = ['111', '101', '104', '222', '228', '207', '209','210','212']

# files used for LSTM
# file_name = ['215', '123']

# these should work but they don't
# '100', '101', '102', '103', '104', '105', '107', '108'

features = ['MLII', 'V1', 'V2', 'V4', 'V5']
labels_list = ['N','S','V','F','Q']


def preprocess(small=False, split=0.0, size=720, save=False):
  full_data = list()
  full_label = list()
  for num in file_name:
    # If small, then sample only 6000
    if small:
      record_file = wfdb.rdrecord("mitdb/"+num, sampto=35000, smooth_frames= True)
    else:
      record_file = wfdb.rdrecord("mitdb/"+num, smooth_frames= True)

    # Obtain signal and peak index
    signals_mlii = preprocessing.scale(np.nan_to_num(record_file.p_signal[:,0]))
    signals_mlii[np.isnan(signals_mlii)] = 0
    signals_mlii = signals_mlii.tolist()
    peaks_mlii, _ = find_peaks(signals_mlii, distance=150)

    # Create data point centered at peak
    for peak in tqdm(peaks_mlii[1:-1]):
      start = peak - size//2
      if start < 0:
        continue
      end = peak + size//2
      if end - start != size:
        continue
      ann = wfdb.rdann("mitdb/"+num, extension="atr", sampfrom = start, sampto = end, return_label_elements=["symbol"])
      annSymbol = ann.symbol

      # If symbol not in label list, ignore this data?
      if len(annSymbol) == 0 or annSymbol[0] not in labels_list:
        continue

      # remove some N classes:
      if annSymbol[0] == 'N' and np.random.random()>0.15:
        continue

      # Create one hot vector
      label_vec = [0] * len(labels_list)
      label_vec[labels_list.index(annSymbol[0])] = 1

      signal = np.asarray(signals_mlii[start:end], dtype=float)
      if np.isnan(signal).any():
        continue
      # append label vector and data vector
      full_label.append(label_vec)
      full_data.append(signal)

  full_data = np.nan_to_num(full_data)

  try:
    full_data = np.asarray(full_data, dtype=float)
  except:
    print("{} caused an error in full data".format(num))
  try:
    full_label = np.asarray(full_label, dtype=float)
  except:
    print("{} caused an error in full label".format(num))
  print(full_data.dtype)

  # If no split, just return
  if split == 0.0:
    return full_data, full_label

  # Split
  X_train, X_test, y_train, y_test = model_selection.train_test_split(full_data, full_label, test_size=split, random_state=11)

  if save:
    # Save
    np.savetxt("processed_data/X_train.csv", X_train)
    np.savetxt("processed_data/y_train.csv", y_train)
    # Save test set if split > 0
    if split > 0.0:
      np.savetxt("processed_data/X_test.csv", X_test)
      np.savetxt("processed_data/y_test.csv", y_test)
  return X_train, y_train, X_test, y_test

# !mkdir processed_data
# Out:
# mkdir: cannot create directory ‘processed_data’: File exists

# %% [markdown]
# ## Neural Network Initializations

# %%
class PrintLayer(nn.Module):
    def __init__(self, p):
        super(PrintLayer, self).__init__()
        self.p = p

    def forward(self, x):
        # Do your print / debug stuff here
        # print(self.p, x.shape)
        return x

# %% [markdown]
# ### CNN

# %%
class CNN_ECG(nn.Module):
    def __init__(self, input_size):
        super().__init__()

        # CNN Layers with Max Pooling
        self.cnn_1 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=5, kernel_size=3, stride=1),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.LeakyReLU(),
        )

        self.cnn_2 = nn.Sequential(
            nn.Conv1d(in_channels=5, out_channels=10, kernel_size=4, stride=1),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.LeakyReLU(),
        )

        self.cnn_3 = nn.Sequential(
            nn.Conv1d(in_channels=10, out_channels=20, kernel_size=4, stride=1),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.LeakyReLU(),
        )

        # Fully Connected Layers
        self.fc = nn.Sequential(
            nn.Linear(in_features=600, out_features=30),
            nn.LeakyReLU(),
            nn.Linear(in_features=30, out_features=20),
            nn.LeakyReLU(),
            nn.Linear(in_features=20, out_features=5),
        )

    def forward(self, x):
        cnn_1_out = self.cnn_1(x)
        cnn_2_out = self.cnn_2(cnn_1_out)
        cnn_3_out = self.cnn_3(cnn_2_out)

        fc_in = cnn_3_out.view([cnn_3_out.shape[0], cnn_3_out.shape[1] * cnn_3_out.shape[2]])
        fc_out = self.fc(fc_in)

        return fc_out

# %% [markdown]
# ### RNN-LSTM

# %%
class RNN_LSTM(nn.Module):
    def __init__(self, input_size, batch_size):
        super(RNN_LSTM, self).__init__()

        self.dense = nn.Sequential(
            nn.Linear(in_features=100, out_features=5),
            nn.Sigmoid()
        )

        self.batch_size = batch_size

        self.lstm1 = nn.LSTMCell(input_size = input_size, hidden_size = 64)
        self.do1 = nn.Dropout(p = 0.2)

        self.lstm2 = nn.LSTMCell(input_size = 64, hidden_size = 256)
        self.do2 = nn.Dropout(p = 0.2)

        self.lstm3 = nn.LSTMCell(input_size = 256, hidden_size = 100)
        self.do3 = nn.Dropout(p = 0.2)

    def forward(self, x):
        """Forward pass of the LSTM
        """

        h_0 = Variable(torch.zeros(x.shape[0], 64))
        c_0 = Variable(torch.zeros(x.shape[0], 64))

        h_1 = Variable(torch.zeros(x.shape[0], 256))
        c_1 = Variable(torch.zeros(x.shape[0], 256))

        h_2 = Variable(torch.zeros(x.shape[0], 100))
        c_2 = Variable(torch.zeros(x.shape[0], 100))

        x = x.squeeze(1)
        for i in range(5):

          h_0, c_0 = self.lstm1(x, (h_0, c_0))
          out1 = self.do1(h_0)
          h_1, c_1 = self.lstm2(out1, (h_1, c_1))
          out2 = self.do1(h_1)
          h_2, c_2 = self.lstm3(out2, (h_2, h_2))
          out3 = self.do1(h_2)

          output = self.dense(out3)

        return output

# %% [markdown]
# ## Functions

# %% [markdown]
# ### CNN

# %%
def train_CNN(lr, X_train, y_train, train_iter):
  batch_size = 256
  input_size = 1 # will be changed later
  model = CNN_ECG(input_size)
  cutoff = 0

  epochs = 20
  criterion = nn.CrossEntropyLoss() # not sure if we should use this
  optimizer = torch.optim.Adam(model.parameters(), lr)

  for epoch in range(epochs + 1):
    total_loss = torch.Tensor([0])

    acc_count = 0
    acc_total = train_iter * batch_size

    for b in range(train_iter):
      batch_idx = np.random.randint(low=0, high=X_train.shape[0] , size=(batch_size,))
      x_batch = X_train[batch_idx]
      y_batch = y_train[batch_idx]

      y_predict = model(x_batch)
      y_predict = torch.squeeze(y_predict)
      loss = criterion(y_predict, y_batch)
      total_loss += loss

      y_batch = y_batch.long()
      y_predict = y_predict.round().detach().numpy()
      y_pred_cutoff = np.where(y_predict > cutoff, 1, 0)
      y_pred_idx = np.argmax(y_predict, axis=1)

      acount = 0

      for i in range(y_pred_cutoff.shape[0]):
        pred = np.zeros(5) ## Number of classes, create 1 hot vec
        pred[y_pred_idx[i]] = 1
        y = y_batch.detach().numpy()

        actual = y[i]
        if (pred == actual).all():
          acount += 1

      acc_count += acount

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

    if epoch % 2 == 0 and epoch != 0:
      print("Epoch {}".format(epoch))
      accuracy = acc_count/acc_total
      print("Loss: ", round(total_loss.item(), 4))
      print("Training Accuracy: ", round(accuracy, 4))
  return model

# %% [markdown]
# ### LSTM

# %%
def train_RNN_LTSM(lr, X_train, y_train, train_iter=3):
  batch_size = 10
  input_size = 720 # just putting a random number for now
  model = RNN_LSTM(input_size, batch_size)

  epochs = 40
  criterion = nn.MSELoss()
  optimizer = torch.optim.Adam(model.parameters(), lr)

  for epoch in range(epochs + 1):
    total_loss = torch.Tensor([0])

    acc_count = 0
    acc_total = train_iter * batch_size

    for b in range(train_iter):
      batch_idx = np.random.randint(low=0, high=X_train.shape[0] , size=(batch_size,))
      x_batch = X_train[batch_idx]
      y_batch = y_train[batch_idx]

      y_predict = model(x_batch)
      loss = criterion(torch.squeeze(y_predict), y_batch)
      total_loss += loss

      y_batch = y_batch.long()
      y_predict = y_predict.round().detach().numpy()
      y_pred_idx = np.argmax(y_predict, axis=1)

      acount = 0

      for i in range(y_predict.shape[0]):
        pred = np.zeros(5) ## Number of classes, create 1 hot vec
        pred[y_pred_idx[i]] = 1
        y = y_batch.detach().numpy()

        actual = y[i]
        if (pred == actual).all():
          acount += 1

      acc_count += acount

      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

    if epoch % 2 == 0 and epoch != 0:
      print("Epoch: {}".format(epoch))
      accuracy = round(acc_count/acc_total, 4)
      print("Loss: ", round(total_loss.item(), 4))
      print("Training Accuracy: ", accuracy)

  return model

# %% [markdown]
# ### Testing

# %%
def test_model(model, X_test, y_test, model_type="cnn"):
  if model_type == "cnn":
    criterion = nn.CrossEntropyLoss()
  else:
    criterion = nn.MSELoss()

  tp = 0
  fp = 0
  fn = 0
  tn = 0
  with torch.no_grad():
    y_predict = model(X_test)
    # loss
    loss = criterion(torch.squeeze(y_predict), y_test)
    # accuracy
    y_test = y_test.long()
    y_predict = y_predict.detach().numpy()
    y_pred_idx = np.argmax(y_predict, axis=1)
    acount = 0
    for i in range(y_predict.shape[0]):
      pred = np.zeros(5) ## Number of classes, create 1 hot vec
      pred[y_pred_idx[i]] = 1
      y = y_test.detach().numpy()

      actual = y[i]
      if (pred == actual).all():
        acount += 1
        if (pred[0] == 1 and actual[0] == 1):
          tp += 1
        elif (pred[0] != 1 and actual[0] != 1):
          tn += 1
      else:
        if (pred[0] == 1 and actual[0] != 1):
          fp += 1
        elif (pred[0] != 1 and actual[0] == 1):
          fn += 1
    accuracy = round(acount/y_predict.shape[0], 4)
    print("Test Loss: ", round(loss.item(), 4))
    print("Testing Accuracy: ", accuracy)
    print("True Positive: ", tp)
    print("True Negative: ", tn)
    print("False Positive: ", fp)
    print("False Negative: ", fn)
    print("sensitivity: ", tp / (tp + fn))
    print("specificity: ", tn / (tn + fp))

# %% [markdown]
# ### Hyperparamters & Other Initializations

# %%
lr = 0.001

# %% [markdown]
# ## Calling Functions

# %%
# !mkdir models

# %%
# !ls
# Out:
# mitdb	physionet.org	processed_data_challenge
# models	processed_data	sample_data

# %% [markdown]
# ### CNN

# %%
X_train, y_train, X_test, y_test = preprocess(False, split=0.3, size=260, save=False)
X_train = torch.Tensor(X_train).unsqueeze(1)
demo = np.sum(y_train, axis=0)
y_train = torch.Tensor(y_train)

print("Demo of Data: ", demo)

model = train_CNN(lr, X_train, y_train, 3)
pickle.dump(model, open('models/cnn', 'wb'))
#Test
X_test = torch.Tensor(X_test).unsqueeze(1)
demo = np.sum(y_test, axis=0)
y_test = torch.Tensor(y_test)
test_model(model, X_test, y_test, "cnn")
# Out:
# 100%|██████████| 2559/2559 [00:53<00:00, 48.06it/s]
# 100%|██████████| 3626/3626 [01:06<00:00, 54.62it/s]
# float64
# Demo of Data:  [7.984e+03 1.000e+00 4.982e+03 5.580e+02 1.800e+01]
# Epoch 2
# Loss:  4.8048
# Training Accuracy:  0.5951
# Epoch 4
# Loss:  4.2648
# Training Accuracy:  0.6185
# Epoch 6
# Loss:  3.2852
# Training Accuracy:  0.599
# Epoch 8
# Loss:  2.4813
# Training Accuracy:  0.6328
# Epoch 10
# Loss:  2.2262
# Training Accuracy:  0.6081
# Epoch 12
# Loss:  2.3126
# Training Accuracy:  0.7188
# Epoch 14
# Loss:  1.9228
# Training Accuracy:  0.776
# Epoch 16
# Loss:  1.3408
# Training Accuracy:  0.8685
# Epoch 18
# Loss:  1.1073
# Training Accuracy:  0.8724
# Epoch 20
# Loss:  1.0163
# Training Accuracy:  0.8815
# Test Loss:  0.3976
# Testing Accuracy:  0.8682
# True Positive:  3168
# True Negative:  0
# False Positive:  431
# False Negative:  244
# sensitivity:  0.9284876905041032
# specificity:  0.0

# %%
# !ls models
# Out:
# cnn  lstm

# %% [markdown]
# ### LSTM

# %%
X_train, y_train, X_test, y_test = preprocess(False, split=0.2, size=720, save=False)
# X_train = X_train.astype(float)
print(X_train.dtype)
X_train = torch.Tensor(X_train).unsqueeze(1)
# X_train = torch.from_numpy(X_train).unsqueeze(1)

demo = np.sum(y_train, axis=0)
y_train = torch.Tensor(y_train)
print("Demo: ", demo)
model = train_RNN_LTSM(lr, X_train, y_train)
pickle.dump(model, open('models/lstm', 'wb'))
#Test
X_test = torch.Tensor(X_test).unsqueeze(1)
demo = np.sum(y_test, axis=0)
y_test = torch.Tensor(y_test)
test_model(model, X_test, y_test, "lstm")
# Out:
# 100%|██████████| 3355/3355 [01:34<00:00, 35.40it/s]
# 100%|██████████| 3122/3122 [00:43<00:00, 71.56it/s]
# float64
# float64
# Demo:  [736.   0. 110.   1.   0.]
# Epoch: 2
# Loss:  0.5883
# Training Accuracy:  0.8667
# Epoch: 4
# Loss:  0.2264
# Training Accuracy:  0.9
# Epoch: 6
# Loss:  0.1163
# Training Accuracy:  0.9
# Epoch: 8
# Loss:  0.1772
# Training Accuracy:  0.8333
# Epoch: 10
# Loss:  0.1445
# Training Accuracy:  0.8667
# Epoch: 12
# Loss:  0.2135
# Training Accuracy:  0.8
# Epoch: 14
# Loss:  0.2082
# Training Accuracy:  0.8
# Epoch: 16
# Loss:  0.142
# Training Accuracy:  0.8667
# Epoch: 18
# Loss:  0.08
# Training Accuracy:  0.9333
# Epoch: 20
# Loss:  0.1416
# Training Accuracy:  0.8667
# Epoch: 22
# Loss:  0.1716
# Training Accuracy:  0.8333
# Epoch: 24
# Loss:  0.1199
# Training Accuracy:  0.9
# Epoch: 26
# Loss:  0.0787
# Training Accuracy:  0.9333
# Epoch: 28
# Loss:  0.1936
# Training Accuracy:  0.8
# Epoch: 30
# Loss:  0.1525
# Training Accuracy:  0.8333
# Epoch: 32
# Loss:  0.175
# Training Accuracy:  0.8
# Epoch: 34
# Loss:  0.1324
# Training Accuracy:  0.8667
# Epoch: 36
MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A00103.hea’ saved [85/85]
#
# --2022-04-20 22:56:50--  https://physionet.org/files/challenge-2017/1.0.0/validation/A00103.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36024 (35K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A00103.mat’
#
# physionet.org/files 100%[===================>]  35.18K  --.-KB/s    in 0.006s
#
# 2022-04-20 22:56:50 (5.78 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A00103.mat’ saved [36024/36024]
#
# --2022-04-20 22:56:50--  https://physionet.org/files/challenge-2017/1.0.0/validation/A00104.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 83 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A00104.hea’
#
# physionet.org/files 100%[===================>]      83  --.-KB/s    in 0s
#
# 2022-04-20 22:56:50 (13.6 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A00104.hea’ saved [83/83]
#
# --2022-04-20 22:56:50--  https://physionet.org/files/challenge-2017/1.0.0/validation/A00104.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18024 (18K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A00104.mat’
#
# physionet.org/files 100%[===================>]  17.60K  --.-KB/s    in 0s
#
# 2022-04-20 22:56:50 (49.6 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A00104.mat’ saved [18024/18024]
#
# --2022-04-20 22:56:50--  https://physionet.org/files/challenge-2017/1.0.0/validation/A00105.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 85 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A00105.hea’
#
# physionet.org/files 100%[===================>]      85  --.-KB/s    in 0s
#
# 2022-04-20 22:56:50 (10.7 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A00105.hea’ saved [85/85]
#
# --2022-04-20 22:56:50--  https://physionet.org/files/challenge-2017/1.0.0/validation/A00105.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36364 (36K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A00105.mat’
#
# physionet.org/files 100%[===================>]  35.51K  --.-KB/s    in 0.003s
#
# ...
# Length: 12184 (12K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04137.mat’
#
# physionet.org/files 100%[===================>]  11.90K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (200 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04137.mat’ saved [12184/12184]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04170.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 84 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04170.hea’
#
# physionet.org/files 100%[===================>]      84  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (12.5 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04170.hea’ saved [84/84]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04170.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18024 (18K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04170.mat’
#
# physionet.org/files 100%[===================>]  17.60K  --.-KB/s    in 0.001s
#
# 2022-04-20 22:57:07 (21.6 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04170.mat’ saved [18024/18024]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04186.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 83 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04186.hea’
#
# physionet.org/files 100%[===================>]      83  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (12.6 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04186.hea’ saved [83/83]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04186.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6300 (6.2K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04186.mat’
#
# physionet.org/files 100%[===================>]   6.15K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (585 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04186.mat’ saved [6300/6300]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04216.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 84 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04216.hea’
#
# physionet.org/files 100%[===================>]      84  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (12.2 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04216.hea’ saved [84/84]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04216.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7224 (7.1K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04216.mat’
#
# physionet.org/files 100%[===================>]   7.05K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (416 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04216.mat’ saved [7224/7224]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04282.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 84 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04282.hea’
#
# physionet.org/files 100%[===================>]      84  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (13.9 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04282.hea’ saved [84/84]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04282.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 21060 (21K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04282.mat’
#
# physionet.org/files 100%[===================>]  20.57K  --.-KB/s    in 0.001s
#
# 2022-04-20 22:57:07 (34.2 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04282.mat’ saved [21060/21060]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04452.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 85 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04452.hea’
#
# physionet.org/files 100%[===================>]      85  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (25.1 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04452.hea’ saved [85/85]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04452.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36024 (35K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04452.mat’
#
# physionet.org/files 100%[===================>]  35.18K  --.-KB/s    in 0.003s
#
# 2022-04-20 22:57:07 (11.0 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04452.mat’ saved [36024/36024]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04522.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 83 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04522.hea’
#
# physionet.org/files 100%[===================>]      83  --.-KB/s    in 0s
#
# 2022-04-20 22:57:07 (23.3 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04522.hea’ saved [83/83]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04522.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18024 (18K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04522.mat’
#
# physionet.org/files 100%[===================>]  17.60K  --.-KB/s    in 0.001s
#
# 2022-04-20 22:57:07 (33.2 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04522.mat’ saved [18024/18024]
#
# --2022-04-20 22:57:07--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04701.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 83 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04701.hea’
#
# physionet.org/files 100%[===================>]      83  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (11.4 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04701.hea’ saved [83/83]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04701.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10776 (11K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04701.mat’
#
# physionet.org/files 100%[===================>]  10.52K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (186 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04701.mat’ saved [10776/10776]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04735.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 83 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04735.hea’
#
# physionet.org/files 100%[===================>]      83  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (11.0 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04735.hea’ saved [83/83]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04735.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18024 (18K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04735.mat’
#
# physionet.org/files 100%[===================>]  17.60K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (80.3 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04735.mat’ saved [18024/18024]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04805.hea
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04805.hea’
#
# physionet.org/files 100%[===================>]      84  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (9.85 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04805.hea’ saved [84/84]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/A04805.mat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18024 (18K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/A04805.mat’
#
# physionet.org/files 100%[===================>]  17.60K  --.-KB/s    in 0.001s
#
# 2022-04-20 22:57:08 (25.4 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/A04805.mat’ saved [18024/18024]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/MD5SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 27484 (27K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/MD5SUMS’
#
# physionet.org/files 100%[===================>]  26.84K  --.-KB/s    in 0.004s
#
# 2022-04-20 22:57:08 (5.87 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/MD5SUMS’ saved [27484/27484]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2100 (2.1K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS’
#
# physionet.org/files 100%[===================>]   2.05K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (256 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS’ saved [2100/2100]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-af
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 329 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-af’
#
# physionet.org/files 100%[===================>]     329  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (51.4 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-af’ saved [329/329]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-noisy
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 280 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-noisy’
#
# physionet.org/files 100%[===================>]     280  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (34.9 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-noisy’ saved [280/280]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-normal
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1036 (1.0K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-normal’
#
# physionet.org/files 100%[===================>]   1.01K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (10.1 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-normal’ saved [1036/1036]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-other
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 455 [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-other’
#
# physionet.org/files 100%[===================>]     455  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (66.2 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/RECORDS-other’ saved [455/455]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v0.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2700 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v0.csv’
#
# physionet.org/files 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (273 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v0.csv’ saved [2700/2700]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v1.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2700 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v1.csv’
#
# physionet.org/files 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (325 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v1.csv’ saved [2700/2700]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v2.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2700 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v2.csv’
#
# physionet.org/files 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (339 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v2.csv’ saved [2700/2700]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v3.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2700 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v3.csv’
#
# physionet.org/files 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (327 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE-v3.csv’ saved [2700/2700]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE.csv
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2700 (2.6K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE.csv’
#
# physionet.org/files 100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-04-20 22:57:08 (377 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/REFERENCE.csv’ saved [2700/2700]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/SHA1SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 32364 (32K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/SHA1SUMS’
#
# physionet.org/files 100%[===================>]  31.61K  --.-KB/s    in 0.003s
#
# 2022-04-20 22:57:08 (10.1 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/SHA1SUMS’ saved [32364/32364]
#
# --2022-04-20 22:57:08--  https://physionet.org/files/challenge-2017/1.0.0/validation/SHA256SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 47004 (46K) [text/plain]
# Saving to: ‘physionet.org/files/challenge-2017/1.0.0/validation/SHA256SUMS’
#
# physionet.org/files 100%[===================>]  45.90K  --.-KB/s    in 0.006s
#
# 2022-04-20 22:57:08 (7.65 MB/s) - ‘physionet.org/files/challenge-2017/1.0.0/validation/SHA256SUMS’ saved [47004/47004]
#
# FINISHED --2022-04-20 22:57:08--
# Total wall clock time: 29s
# Downloaded: 614 files, 5.7M in 0.3s (19.6 MB/s)

# %%
path = 'physionet.org/files/challenge-2017/1.0.0/'
# record and annotation for sample 100
record_train = wfdb.rdrecord(path + 'training/A00/A00001', sampto=3000)

# %%
wfdb.plot_wfdb(record=record_train, plot_sym=True,
                   time_units='seconds', title='Challenge-2017 Record A00 A00001',
                   figsize=(10,4), ecg_grids='all')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2092         ratio : float
#    2093             The ratio of logical to physical pixels used for the canvas.
# -> 2094
#    2095         Returns
#    2096         -------
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in _get_renderer(figure, print_method)
#    1558     figure.draw_without_rendering()
#    1559
# -> 1560
#    1561 def _is_non_interactive_terminal_ipython(ip):
#    1562     """
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     503             Metadata in the PNG file as key-value pairs of bytes or latin-1
#     504             encodable strings.
# --> 505             According to the PNG specification, keys must be shorter than 79
#     506             chars.
#     507
#
# ImportError: cannot import name '_png' from 'matplotlib' (/usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py)

# %% [markdown]
# Initializations

# %%
training = True

# %% [markdown]
# ### Loading Dataset

# %%
location = "validation/"
if training:
  location = "training/"

file_af = []
f = open(path + location + "RECORDS-af", "r")
for line in f:
  file_af.append(line[:-1])

f.close()

file_noisy = []
f = open(path + location + "RECORDS-noisy", "r")
for line in f:
  file_noisy.append(line[:-1])

f.close()

file_normal = []
f = open(path + location + "RECORDS-normal", "r")
for line in f:
  file_normal.append(line[:-1])

f.close()

file_other = []
f = open(path + location + "RECORDS-other", "r")
for line in f:
  file_other.append(line[:-1])

f.close()


file_name = file_af + file_noisy + file_normal + file_other
np.random.shuffle(file_name)
file_name = file_name[:len(file_name) // 4]

# %%
labels_list = ['AF','NOISY','NORMAL','OTHER']

def preprocess_challenge(small=False, split=0.0, size=720, save=False):
  full_data = list()
  full_label = list()
  for num in file_name:
    # If small, then sample only 6000
    if small:
      record_file = wfdb.rdrecord(path + location + num, sampto=3000, smooth_frames= True)
    else:
      record_file = wfdb.rdrecord(path + location + num, smooth_frames= True)

    # Find label of current data
    label = -1
    if num in file_af:
      label = 0
    elif num in file_noisy:
      label = 1
    elif num in file_normal:
      label = 2
    elif num in file_other:
      label = 3
    else:
      label = "-1"

    # Obtain signal and peak index
    signals_mlii = preprocessing.scale(np.nan_to_num(record_file.p_signal[:,0]))
    signals_mlii[np.isnan(signals_mlii)] = 0
    signals_mlii = signals_mlii.tolist()
    peaks_mlii, _ = find_peaks(signals_mlii, distance=150)

    # Create data point centered at peak
    for peak in tqdm(peaks_mlii[1:-1]):
      max_size = 0
      start = peak - size//2
      if start < 0:
        continue
      end = peak + size//2

      # remove some N classes:
      if label == 2 and np.random.random()>0.15:
        continue

      # Create one hot vector
      label_vec = [0] * (len(labels_list) + 1)
      label_vec[label] = 1
      label_vec = np.asarray(label_vec, dtype=float)

      signal = np.asarray(signals_mlii[start:end], dtype=float)
      if np.isnan(signal).any():
        continue
      # Padding lists
      if len(signal) < max_size:
        signal.extend([0] * (max_size - len(signal)))
      else:
        max_size = len(signal)
      # append label vector and data vector
      full_label.append(label_vec)
      full_data.append(signal)

  full_data = np.nan_to_num(full_data)
  full_data = np.asarray(full_data, dtype=float)
  full_label = np.asarray(full_label, dtype=float)

  # If no split, just return
  if save:
  # Save
    np.savetxt("processed_data_challenge/data_lstm.csv", full_data)
    np.savetxt("processed_data_challenge/label_lstm.csv", full_label)
  if split == 0.0:
    return full_data, full_label

  # Split
  X_train, X_test, y_train, y_test = model_selection.train_test_split(full_data, full_label, test_size=split, random_state=11)

  print(type(X_train))

  print("train shape:")
  print(X_train.shape)
  print(y_train.shape)

  print("test shape:")
  print(X_test.shape)
  print(y_test.shape)


    # Save test set if split > 0
  #   if split > 0.0:
  #     np.savetxt("processed_data_challenge/X_test.csv", X_test)
  #     np.savetxt("processed_data_challenge/y_test.csv", y_test)
  # return X_train, y_train, X_test, y_test

# !mkdir processed_data
# X_train, y_train, X_test, y_test = preprocess(True, split=0.3, size=260, save=False)
# print(np.sum(y_train, axis=0))
# print(np.sum(y_test, axis=0))
# print(y_train)
# print(y_test)

# %% [markdown]
# ### Testing Both Networks with the Challenge Dataset

# %%
# !mkdir processed_data_challenge

# %% [markdown]
# CNN

# %%
# X_train = X_train.unsqueeze(-1)
data, label = preprocess_challenge(False, split=0.0, size=260, save=False)
data_test, label_test = preprocess_challenge(False, split=0.0, size=260, save=False)
#Test
32it/s]
# 100%|██████████| 40/40 [00:00<00:00, 36519.84it/s]
# 100%|██████████| 15/15 [00:00<00:00, 10510.28it/s]
# 100%|██████████| 33/33 [00:00<00:00, 44419.78it/s]
# 100%|██████████| 33/33 [00:00<00:00, 46137.34it/s]
# 100%|██████████| 43/43 [00:00<00:00, 8399.55it/s]
# 100%|██████████| 39/39 [00:00<00:00, 10975.43it/s]
# 100%|██████████| 38/38 [00:00<00:00, 48371.34it/s]
# 100%|██████████| 39/39 [00:00<00:00, 60561.96it/s]
# 100%|██████████| 38/38 [00:00<00:00, 11154.28it/s]
# 100%|██████████| 41/41 [00:00<00:00, 12261.42it/s]
# 100%|██████████| 38/38 [00:00<00:00, 8355.19it/s]
# 100%|██████████| 41/41 [00:00<00:00, 40711.76it/s]
# 100%|██████████| 26/26 [00:00<00:00, 18102.91it/s]
# 100%|██████████| 25/25 [00:00<00:00, 14204.50it/s]
# 100%|██████████| 37/37 [00:00<00:00, 47473.00it/s]
# 100%|██████████| 74/74 [00:00<00:00, 82767.60it/s]
# 100%|██████████| 31/31 [00:00<00:00, 51474.04it/s]
# 100%|██████████| 32/32 [00:00<00:00, 28963.69it/s]
# 100%|██████████| 33/33 [00:00<00:00, 33660.51it/s]
# 100%|██████████| 25/25 [00:00<00:00, 11021.40it/s]
# 100%|██████████| 75/75 [00:00<00:00, 83441.06it/s]
# torch.Size([182312, 1, 260]) torch.Size([182312, 5])
# Test Loss:  2.9158
# Testing Accuracy:  0.179
# True Positive:  27460
# True Negative:  5165
# False Positive:  116945
# False Negative:  5551
# sensitivity:  0.8318439308109418
# specificity:  0.042297928097616906

# %%
# !ls physionet.org/files/challenge-2017/1.0.0/training/
# Out:
# A00  A04  A08	      RECORDS-af      REFERENCE.csv	REFERENCE-v3.csv
# A01  A05  index.html  RECORDS-noisy   REFERENCE-v0.csv	SHA1SUMS
# A02  A06  MD5SUMS     RECORDS-normal  REFERENCE-v1.csv	SHA256SUMS
# A03  A07  RECORDS     RECORDS-other   REFERENCE-v2.csv

# %%
# sensitivity cnn
# Load CNN Data
from numpy import genfromtxt
import pickle
# !unzip 260_processed.zip

X_train = genfromtxt('processed_data_260/X_train.csv')
y_train = genfromtxt('processed_data_260/y_train.csv')
X_test = genfromtxt('processed_data_260/X_test.csv')
y_test = genfromtxt('processed_data_260/y_test.csv')

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)
model = CNN_ECG(260)
model.load_state_dict(torch.load('cnn_full_model.pth'))
# model = torch.load('cnn_full_model.pth')

demo = np.sum(y_train, axis=0)
print("Demo of Data: ", demo)
X_test = torch.Tensor(X_test).unsqueeze(1)
demo = np.sum(y_test, axis=0)
y_test = torch.Tensor(y_test)
test_model(model, X_test, y_test, "cnn")

# %%
# sensitivity LSTM
# Load LSTM Data
from numpy import genfromtxt
import pickle
# !unzip processed_data_8f.zip

X_train = genfromtxt('processed_data_8f/X_train.csv')
y_train = genfromtxt('processed_data_8f/y_train.csv')
X_test = genfromtxt('processed_data_8f/X_test.csv')
y_test = genfromtxt('processed_data_8f/y_test.csv')

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)
model = RNN_LSTM(720, 256)
model.load_state_dict(torch.load('lstm_model.pth'))
# model = torch.load('cnn_full_model.pth')

demo = np.sum(y_train, axis=0)
print("Demo of Data: ", demo)
X_test = torch.Tensor(X_test).unsqueeze(1)
demo = np.sum(y_test, axis=0)
y_test = torch.Tensor(y_test)
test_model(model, X_test, y_test, "cnn")
